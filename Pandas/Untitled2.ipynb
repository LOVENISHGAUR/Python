# %%
# Render our plots inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Reading Data</h1>
#
# Data: <a href ="https://github.com/LOVENISHGAUR/Python/tree/master/Pandas/Data">Weight1.csv</a>

# %%
#Reading csv file
Raw = pd.read_csv('Weight1.csv')

# Look at the first 10 rows
Raw[:10]
# Out:
#        Date  Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# 0  01/01/20            26            18                 13       145
# 1  02/01/20            27            12                 19       124
# 2  03/01/20            22            15                 22       111
# 3  04/01/20            22            11                 11       104
# 4  05/01/20            30            16                 20       114
# 5  06/01/20            27            14                 13       106
# 6  07/01/20            22            17                 14       106
# 7  08/01/20            27            15                 10       127
# 8  09/01/20            21            17                 25       122
# 9  10/01/20            28            17                 24       134
#
#    Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# 0            98                     4                     3
# 1           100                     3                     2
# ...

# %%
data = pd.read_csv('Weight1.csv', dayfirst=True, index_col=0) # Reading CSV file and setting the index 
data [:10]# Checking the firest 10 columns
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# Date
# 01/01/20            26            18                 13       145
# 02/01/20            27            12                 19       124
# 03/01/20            22            15                 22       111
# 04/01/20            22            11                 11       104
# 05/01/20            30            16                 20       114
# 06/01/20            27            14                 13       106
# 07/01/20            22            17                 14       106
# 08/01/20            27            15                 10       127
# 09/01/20            21            17                 25       122
# 10/01/20            28            17                 24       134
#
#           Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# Date
# 01/01/20            98                     4                     3
# 02/01/20           100                     3                     2
# ...

# %% [markdown]
# <h1>Describing Data</h1>

# %%
data.head() # Getting the view of data by looking at first 5 rows
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# Date
# 01/01/20            26            18                 13       145
# 02/01/20            27            12                 19       124
# 03/01/20            22            15                 22       111
# 04/01/20            22            11                 11       104
# 05/01/20            30            16                 20       114
#
#           Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# Date
# 01/01/20            98                     4                     3
# 02/01/20           100                     3                     2
# 03/01/20            99                     5                     3
# 04/01/20           100                     6                     3
# 05/01/20            97                     6                     2
#
#           Calories_Burnt(Kcal) Weight_72
# Date
# 01/01/20                   311       Yes
# 02/01/20                   320        No
# ...

# %%
data.tail()# Getting the view of data by looking at last 5 rows
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# Date
# 27/02/20            30            16                 17       145
# 28/02/20            21            18                 11       133
# 29/02/20            29            15                 16       110
# 01/03/20            21            15                 20       124
# 02/03/20            22            17                 13       145
#
#           Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# Date
# 27/02/20            97                     4                     1
# 28/02/20           100                     4                     3
# 29/02/20            99                     4                     1
# 01/03/20           100                     6                     1
# 02/03/20            98                     3                     3
#
#           Calories_Burnt(Kcal) Weight_72
# Date
# 27/02/20                   275       Yes
# 28/02/20                   291       Yes
# ...

# %%
data.dtypes# Checking the data types
# Out:
# Run(Minutes)             int64
# Jog(Minutes)             int64
# Exercise(Minutes)        int64
# Hearbeat                 int64
# Body_Temp(F)             int64
# Running_Distance(Km)     int64
# Jogging_Distance(Km)     int64
# Calories_Burnt(Kcal)     int64
# Weight_72               object
# dtype: object

# %%
data.shape # checking the structure of the data frame
# Out:
# (62, 9)

# %%
data.ndim # Checking the dimension of the data frame
# Out:
# 2

# %%
data.describe() # Deascribing the data
# Out:
#        Run(Minutes)  Jog(Minutes)  Exercise(Minutes)    Hearbeat  \
# count     62.000000     62.000000          62.000000   62.000000
# mean      24.854839     15.258065          17.451613  124.387097
# std        3.401286      3.130681           4.678789   13.807048
# min       20.000000     10.000000          10.000000  100.000000
# 25%       22.000000     12.000000          13.250000  111.500000
# 50%       25.000000     16.000000          18.000000  124.500000
# 75%       27.750000     17.750000          21.000000  134.750000
# max       30.000000     20.000000          25.000000  149.000000
#
#        Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# count     62.000000             62.000000             62.000000
# mean      98.629032              4.467742              1.983871
# std        1.119629              1.112046              0.757302
# min       97.000000              3.000000              1.000000
# ...

# %%
data['Hearbeat'].describe() # Describing specific column 'Heartbeats'
# Out:
# count     62.000000
# mean     124.387097
# std       13.807048
# min      100.000000
# 25%      111.500000
# 50%      124.500000
# 75%      134.750000
# max      149.000000
# Name: Hearbeat, dtype: float64

# %%
data['Running_Distance(Km)'].describe() # Describing specific column 'Running_Distance'
# Out:
# count    62.000000
# mean      4.467742
# std       1.112046
# min       3.000000
# 25%       3.250000
# 50%       4.500000
# 75%       5.000000
# max       6.000000
# Name: Running_Distance(Km), dtype: float64

# %%
data['Jogging_Distance(Km)'].describe()# Describing specific column 'Jogging_Distance'
# Out:
# count    62.000000
# mean      1.983871
# std       0.757302
# min       1.000000
# 25%       1.000000
# 50%       2.000000
# 75%       3.000000
# max       3.000000
# Name: Jogging_Distance(Km), dtype: float64

# %%
data.isnull() # Checking for Null values
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# Date
# 01/01/20         False         False              False     False
# 02/01/20         False         False              False     False
# 03/01/20         False         False              False     False
# 04/01/20         False         False              False     False
# 05/01/20         False         False              False     False
# ...                ...           ...                ...       ...
# 27/02/20         False         False              False     False
# 28/02/20         False         False              False     False
# 29/02/20         False         False              False     False
# 01/03/20         False         False              False     False
# 02/03/20         False         False              False     False
#
#           Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# Date
# 01/01/20         False                 False                 False
# ...

# %%
data.mean() # Finding the mean of the data set
# Out:
# Run(Minutes)             24.854839
# Jog(Minutes)             15.258065
# Exercise(Minutes)        17.451613
# Hearbeat                124.387097
# Body_Temp(F)             98.629032
# Running_Distance(Km)      4.467742
# Jogging_Distance(Km)      1.983871
# Calories_Burnt(Kcal)    277.096774
# dtype: float64

# %% [markdown]
# <h1> Selecting a column</h1>

# %%
data.columns # Checking al the columns of the data set
# Out:
# Index(['Run(Minutes)', 'Jog(Minutes)', 'Exercise(Minutes)', 'Hearbeat',
#        'Body_Temp(F)', 'Running_Distance(Km)', 'Jogging_Distance(Km)',
#        'Calories_Burnt(Kcal)', 'Weight_72'],
#       dtype='object')

# %%
data['Run(Minutes)']
# Out:
# Date
# 01/01/20    26
# 02/01/20    27
# 03/01/20    22
# 04/01/20    22
# 05/01/20    30
#             ..
# 27/02/20    30
# 28/02/20    21
# 29/02/20    29
# 01/03/20    21
# 02/03/20    22
# Name: Run(Minutes), Length: 62, dtype: int64

# %%
data[['Run(Minutes)','Jog(Minutes)','Exercise(Minutes)']]
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)
# Date
# 01/01/20            26            18                 13
# 02/01/20            27            12                 19
# 03/01/20            22            15                 22
# 04/01/20            22            11                 11
# 05/01/20            30            16                 20
# ...                ...           ...                ...
# 27/02/20            30            16                 17
# 28/02/20            21            18                 11
# 29/02/20            29            15                 16
# 01/03/20            21            15                 20
# 02/03/20            22            17                 13
#
# [62 rows x 3 columns]

# %% [markdown]
# <h1>Plotting a column</h1>

# %%
data.plot(figsize= (10,8))

# %%
data['Calories_Burnt(Kcal)'].plot()

# %%
data.plot(figsize=(10, 6))
plt.show()

# %% [markdown]
# <h1>Finding NA values in data</h1>

# %%
data.isnull()
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# Date
# 01/01/20         False         False              False     False
# 02/01/20         False         False              False     False
# 03/01/20         False         False              False     False
# 04/01/20         False         False              False     False
# 05/01/20         False         False              False     False
# ...                ...           ...                ...       ...
# 27/02/20         False         False              False     False
# 28/02/20         False         False              False     False
# 29/02/20         False         False              False     False
# 01/03/20         False         False              False     False
# 02/03/20         False         False              False     False
#
#           Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# Date
# 01/01/20         False                 False                 False
# ...

# %%
data.apply(len)
# Out:
# Run(Minutes)            62
# Jog(Minutes)            62
# Exercise(Minutes)       62
# Hearbeat                62
# Body_Temp(F)            62
# Running_Distance(Km)    62
# Jogging_Distance(Km)    62
# Calories_Burnt(Kcal)    62
# Weight_72               62
# dtype: int64

# %% [markdown]
# <h1>Filtering Data</h1>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 62 entries, 01/01/20 to 02/03/20
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Run(Minutes)          62 non-null     int64
#  1   Jog(Minutes)          62 non-null     int64
#  2   Exercise(Minutes)     62 non-null     int64
#  3   Hearbeat              62 non-null     int64
#  4   Body_Temp(F)          62 non-null     int64
#  5   Running_Distance(Km)  62 non-null     int64
#  6   Jogging_Distance(Km)  62 non-null     int64
#  7   Calories_Burnt(Kcal)  62 non-null     int64
#  8   Weight_72             62 non-null     object
# dtypes: int64(8), object(1)
# memory usage: 7.3+ KB

# %%
data.loc[:,'Weight_72']
# Out:
# Date
# 01/01/20    Yes
# 02/01/20     No
# 03/01/20    Yes
# 04/01/20    Yes
# 05/01/20     No
#            ...
# 27/02/20    Yes
# 28/02/20    Yes
# 29/02/20    Yes
# 01/03/20    Yes
# 02/03/20    Yes
# Name: Weight_72, Length: 62, dtype: object

# %%
# Finding running distance more than 2 Km
run_2 = data['Running_Distance(Km)'] >=2
run_2
# Out:
# Date
# 01/01/20    True
# 02/01/20    True
# 03/01/20    True
# 04/01/20    True
# 05/01/20    True
#             ...
# 27/02/20    True
# 28/02/20    True
# 29/02/20    True
# 01/03/20    True
# 02/03/20    True
# Name: Running_Distance(Km), Length: 62, dtype: bool

# %%
data[run_2]
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# Date
# 01/01/20            26            18                 13       145
# 02/01/20            27            12                 19       124
# 03/01/20            22            15                 22       111
# 04/01/20            22            11                 11       104
# 05/01/20            30            16                 20       114
# ...                ...           ...                ...       ...
# 27/02/20            30            16                 17       145
# 28/02/20            21            18                 11       133
# 29/02/20            29            15                 16       110
# 01/03/20            21            15                 20       124
# 02/03/20            22            17                 13       145
#
#           Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# Date
# 01/01/20            98                     4                     3
# ...

# %%
data.loc[run_2,'Body_Temp(F)']
# Out:
# Date
# 01/01/20     98
# 02/01/20    100
# 03/01/20     99
# 04/01/20    100
# 05/01/20     97
#            ...
# 27/02/20     97
# 28/02/20    100
# 29/02/20     99
# 01/03/20    100
# 02/03/20     98
# Name: Body_Temp(F), Length: 62, dtype: int64

# %%
Calories = [230,231,232,233,234,235,236,237,238,239,240]
Filt = data['Calories_Burnt(Kcal)'].isin(Calories)

# %%
data[Filt]
# Out:
#           Run(Minutes)  Jog(Minutes)  Exercise(Minutes)  Hearbeat  \
# Date
# 04/01/20            22            11                 11       104
# 08/01/20            27            15                 10       127
# 25/02/20            21            17                 24       114
# 29/02/20            29            15                 16       110
#
#           Body_Temp(F)  Running_Distance(Km)  Jogging_Distance(Km)  \
# Date
# 04/01/20           100                     6                     3
# 08/01/20            99                     3                     1
# 25/02/20            98                     4                     1
# 29/02/20            99                     4                     1
#
#           Calories_Burnt(Kcal) Weight_72
# Date
# 04/01/20                   239       Yes
# 08/01/20                   234        No
# 25/02/20                   231       Yes
# 29/02/20                   237       Yes

# %% [markdown]
# <H1>Plotting Data</H1>

# %%
data.plot.hist(x= 'Calories_Burnt(Kcal)', y='Run(Minutes)')

# %%
data.plot.line(figsize=(15,10), subplots=True)
plt.show()

# %%
import matplotlib
from matplotlib import pyplot as plt
matplotlib.use('macosx')

# %%
plt.bar('Running_Distance(Km)','Calories_Burnt(Kcal)',data=data,color = 'b',align='center')
plt.xlabel('Calories Burnt')
plt.ylabel("Running Distance ")
plt.title('Distance Run vs Calories Burnt')
plt.show()

# %%
data.columns
# Out:
# Index(['Run(Minutes)', 'Jog(Minutes)', 'Exercise(Minutes)', 'Hearbeat',
#        'Body_Temp(F)', 'Running_Distance(Km)', 'Jogging_Distance(Km)',
#        'Calories_Burnt(Kcal)', 'Weight_72'],
#       dtype='object')

# %%
color = [1]
plt.scatter('Run(Minutes)','Jog(Minutes)',c = color)

# %% [markdown]
# <h1>Plotting with categorical variables</h1>

# %%
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar('Weight_72','Run(Minutes)' , data=data)
plt.subplot(132)
plt.scatter('Weight_72','Run(Minutes)' , data=data)
plt.subplot(133)
plt.plot('Weight_72','Run(Minutes)' , data=data)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
plt.figure(figsize=(9, 3))

plt.subplot(131)
plt.bar('Weight_72','Run(Minutes)' , data=data)
plt.subplot(132)
plt.bar('Weight_72','Jog(Minutes)' , data=data)
plt.subplot(133)
plt.bar('Weight_72','Exercise(Minutes)' , data=data)
plt.suptitle('Categorical Plotting')
plt.show()
